# %%
# %matplotlib inline
from citipy import citipy
import json
import csv
import requests
import gmaps
from config import apikey
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import linregress
import time

# %%
#citypy documentation for ref
#city = citipy.nearest_city(-161.27553690072585, -25.120298028273737)
#city.city_name

# %%
#Setting up a random counter of cordinates 
from random import uniform
x, y = uniform(-180,180), uniform(-90, 90)
x, y
list_cities = []

# %%
#Loop gathering list of apx 500 cities 

while len(list_cities) <= 575:
    x, y = uniform(-180,180), uniform(-90, 90)
    city = citipy.nearest_city(x, y)
    if city.city_name not in list_cities:
        list_cities.append(city.city_name)
        city = 0
else:
    city = 0
#print(list_cities)

# %%
#converting to data frame, and checking for duplicates
cities = pd.DataFrame({"Cities": list_cities})
#cities.Cities.duplicated()
cities.head()
# Out:
#         Cities
# 0      ushuaia
# 1  barentsburg
# 2       narsaq
# 3    taolanaro
# 4       dikson

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={apikey}&units={units}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=3bb7b80efb6c69cc146b3fb704a1e9a8&units=imperial&q='

# %%
temp = []
lat = []
lon = []
windspd = []
humidity = []
cloudiness = []
new_name = []

for city in cities["Cities"]:
    try:
        resp = requests.get(query_url + city).json()
        print(f"The city name is "+ resp["name"] + " & the city id is " + str(resp["id"]))
        lat.append(resp['coord']['lat'])
        new_name.append(resp["name"])
        lon.append(resp["coord"]["lon"])
        windspd.append(resp["wind"]["speed"])
        humidity.append(resp["main"]["humidity"])
        temp.append(resp["main"]["temp"])
        cloudiness.append(resp["clouds"]["all"])
        time.sleep(1.1)
    except KeyError:
        print("CITY NOT VALID")
        time.sleep(1.1)
# Out:
# The city name is Ushuaia & the city id is 3833367
# CITY NOT VALID
# The city name is Narsaq & the city id is 3421719
# CITY NOT VALID
# The city name is Dikson & the city id is 1507390
# The city name is Longyearbyen & the city id is 2729907
# The city name is Qaanaaq & the city id is 3831208
# The city name is Marawi & the city id is 1701054
# CITY NOT VALID
# The city name is Port Alfred & the city id is 964432
# The city name is Busselton & the city id is 2075265
# The city name is Albany & the city id is 5106841
# The city name is Hermanus & the city id is 3366880
# The city name is Altamira & the city id is 3407882
# CITY NOT VALID
# CITY NOT VALID
# The city name is Hobyo & the city id is 57000
# The city name is Mandeville & the city id is 3489577
# CITY NOT VALID
# The city name is Huarmey & the city id is 3939168
# The city name is Bredasdorp & the city id is 1015776
# The city name is Saint-Philippe & the city id is 935215
# The city name is Touros & the city id is 3386213
# The city name is Punta Arenas & the city id is 3874787
# The city name is Kulu & the city id is 305742
# The city name is Souillac & the city id is 933995
# The city name is Pisco & the city id is 3932145
# The city name is Mosquera & the city id is 3674292
# The city name is General Roca & the city id is 3855065
# The city name is The Valley & the city id is 3573374
# The city name is Castro & the city id is 3466704
# The city name is Tasiilaq & the city id is 3424607
# The city name is Marsabit & the city id is 187585
# The city name is Goderich & the city id is 5962442
# The city name is Suruc & the city id is 300075
# The city name is Normandin & the city id is 6089179
# The city name is Upernavik & the city id is 3418910
# The city name is Sakskobing & the city id is 2614328
# CITY NOT VALID
# CITY NOT VALID
# The city name is Hong Kong & the city id is 1819729
# The city name is Grindavik & the city id is 3416888
# The city name is Sao Joao da Barra & the city id is 3448903
# The city name is Porbandar & the city id is 1259395
# The city name is Benguela & the city id is 3351663
# The city name is Rawson & the city id is 3839307
# The city name is Sao Felipe & the city id is 3449216
# The city name is Darnah & the city id is 87205
# The city name is Jamestown & the city id is 5122534
# The city name is Port Elizabeth & the city id is 964420
# The city name is Talnakh & the city id is 1490256
# The city name is Valparaiso & the city id is 3868626
# The city name is Quelimane & the city id is 1028434
# The city name is Los Llanos de Aridane & the city id is 2514651
# CITY NOT VALID
# The city name is Caiaponia & the city id is 3468234
# The city name is Sistranda & the city id is 3139597
# The city name is Constitucion & the city id is 3893726
# The city name is Iqaluit & the city id is 5983720
# CITY NOT VALID
# The city name is Lebu & the city id is 3883457
# CITY NOT VALID
# The city name is Nerja & the city id is 2513240
# The city name is Ponta Delgada & the city id is 3372783
# The city name is Torbay & the city id is 6167817
# The city name is Florianopolis & the city id is 6323121
# The city name is Bloemfontein & the city id is 1018725
# The city name is Saint George & the city id is 5546220
# The city name is Cape Town & the city id is 3369157
# The city name is Sechura & the city id is 3691954
# The city name is Cidreira & the city id is 3466165
# The city name is Vila Franca do Campo & the city id is 3372472
# The city name is Nuuk & the city id is 3421319
# The city name is Dubrovnik & the city id is 3201047
# The city name is Nova Venecia & the city id is 3456110
# The city name is George Town & the city id is 1735106
# The city name is Pangnirtung & the city id is 6096551
# The city name is Kruisfontein & the city id is 986717
# CITY NOT VALID
# CITY NOT VALID
# The city name is Shieli & the city id is 1524801
# The city name is Saerevere & the city id is 588792
# The city name is Srebrenica & the city id is 3190159
# The city name is Santa Isabel do Rio Negro & the city id is 3662489
# The city name is East London & the city id is 1006984
# The city name is Arraial do Cabo & the city id is 3471451
# The city name is Chui & the city id is 3443061
# CITY NOT VALID
# The city name is Askarovo & the city id is 580584
# The city name is Santa Helena de Goias & the city id is 3450206
# The city name is Ostrovnoy & the city id is 556268
# The city name is Manchester & the city id is 2643123
# The city name is Daoukro & the city id is 2290412
# The city name is Vardo & the city id is 777019
# The city name is Coquimbo & the city id is 3893629
# The city name is Gornopravdinsk & the city id is 1506268
# CITY NOT VALID
# The city name is Oranjemund & the city id is 3354071
# The city name is Channahon & the city id is 4887198
# The city name is Shache & the city id is 1280037
# The city name is Lircay & the city id is 3928317
# The city name is Japura & the city id is 1642773
# The city name is Bay Saint Louis & the city id is 4417205
# The city name is Bambous Virieux & the city id is 1106677
# The city name is Tessalit & the city id is 2449893
# The city name is Mangai & the city id is 2313084
# The city name is Vicuna & the city id is 3868308
# The city name is Olinda & the city id is 3393536
# The city name is Montepuez & the city id is 1037125
# The city name is Lagoa & the city id is 3372964
# The city name is Muzhi & the city id is 1498161
# The city name is Chabahar & the city id is 1161724
# The city name is Mobaye & the city id is 237478
# The city name is Guaruja & the city id is 3461789
# The city name is Acarau & the city id is 3408368
# CITY NOT VALID
# The city name is Hithadhoo & the city id is 1282256
# The city name is Nkayi & the city id is 2259383
# CITY NOT VALID
# The city name is Quryq & the city id is 609919
# The city name is Mersa Matruh & the city id is 352733
# The city name is Yei & the city id is 363619
# The city name is Mar del Plata & the city id is 3430863
# The city name is Eyl & the city id is 60019
# The city name is Sur & the city id is 286245
# The city name is Shahgarh & the city id is 1256734
# The city name is Salalah & the city id is 286621
# The city name is Codrington & the city id is 2171099
# The city name is Moen & the city id is 3145649
# The city name is At-Bashi & the city id is 1528796
# The city name is Springbok & the city id is 3361142
# The city name is Ilulissat & the city id is 3423146
# The city name is Takoradze & the city id is 2294915
# The city name is Nizhnevartovsk & the city id is 1497543
# The city name is Kintampo & the city id is 2299625
# The city name is Shirgaon & the city id is 1256486
# The city name is Lekoni & the city id is 2399831
# The city name is Nanortalik & the city id is 3421765
# The city name is Cantagalo & the city id is 3467445
# The city name is Cairo & the city id is 360630
# The city name is Ratanpur & the city id is 1258362
# The city name is Ponta do Sol & the city id is 2264557
# The city name is Berlevag & the city id is 780687
# The city name is Surubim & the city id is 3387115
# The city name is Bellavista & the city id is 3699364
# The city name is Ivanjica & the city id is 789988
# The city name is Lodja & the city id is 211647
# The city name is Tocopilla & the city id is 3869716
# CITY NOT VALID
# The city name is Olafsvik & the city id is 3414079
# The city name is Point Pedro & the city id is 1229989
# The city name is Sakakah & the city id is 102527
# The city name is Sangueya & the city id is 2416061
# The city name is Rundu & the city id is 3353383
# The city name is Margate & the city id is 2643044
# The city name is Puerto Ayora & the city id is 3652764
# The city name is Ndioum & the city id is 2247684
# The city name is Mana & the city id is 3381041
# The city name is Skjervoy & the city id is 777682
# The city name is Weligama & the city id is 1223738
# The city name is Jaguariaiva & the city id is 3460214
# The city name is Rumford & the city id is 4977125
# CITY NOT VALID
# The city name is San Cristobal & the city id is 3628473
# The city name is Palagiano & the city id is 6537567
# The city name is Baglung & the city id is 1283711
# The city name is Apeldoorn & the city id is 2759706
# The city name is Vila Velha & the city id is 3445026
# The city name is Mahebourg & the city id is 934322
# The city name is Zhezkazgan & the city id is 1516589
# The city name is Doha & the city id is 290030
# The city name is Terme & the city id is 738803
# The city name is Husavik & the city id is 2629833
# The city name is Ribeira Grande & the city id is 3372707
# The city name is Sao Filipe & the city id is 3374210
# The city name is Inta & the city id is 1505579
# The city name is Sao Gabriel da Cachoeira & the city id is 3662342
# The city name is Vestmannaeyjar & the city id is 3412093
# The city name is Sept-Iles & the city id is 6144312
# The city name is Bathurst & the city id is 2176632
# The city name is Nalut & the city id is 2214432
# The city name is Roald & the city id is 3141667
# The city name is Beyneu & the city id is 610298
# The city name is Vestmanna & the city id is 2610343
# The city name is Pangody & the city id is 1495626
# The city name is Matadi & the city id is 2313002
# The city name is La Mana & the city id is 3655117
# The city name is Nouadhibou & the city id is 2377457
# The city name is Tenenkou & the city id is 2449938
# The city name is Iquique & the city id is 3887127
# The city name is Praia da Vitoria & the city id is 3372760
# The city name is Fort Myers Beach & the city id is 4155996
# The city name is Gamba & the city id is 2400547
# The city name is Kibala & the city id is 2425791
# The city name is Concarneau & the city id is 3024035
# The city name is Razvilnoye & the city id is 510613
# The city name is Muros & the city id is 3115824
# The city name is Ukmerge & the city id is 593733
# The city name is Esil & the city id is 1524296
# The city name is San Fernando & the city id is 1690039
# The city name is Aripuana & the city id is 3665202
# The city name is Taltal & the city id is 3870243
# The city name is Henties Bay & the city id is 3356832
# The city name is Bilokurakyne & the city id is 712569
# The city name is Ibiruba & the city id is 3461559
# The city name is Cienfuegos & the city id is 3564124
# The city name is Saldanha & the city id is 3361934
# CITY NOT VALID
# The city name is Findhorn & the city id is 2649438
# The city name is Bajos de Haina & the city id is 3512128
# The city name is Anori & the city id is 3665315
# The city name is Itarema & the city id is 3393692
# CITY NOT VALID
# The city name is Pivijay & the city id is 3672093
# The city name is Plaster Rock & the city id is 7290171
# The city name is Andenes & the city id is 3163146
# The city name is Cap Malheureux & the city id is 934649
# The city name is Lola & the city id is 2418092
# The city name is Mauriti & the city id is 3395058
# The city name is Killybegs & the city id is 2963295
# The city name is Sandusky & the city id is 5170698
# The city name is Saint Anthony & the city id is 5044290
# The city name is Najran & the city id is 103630
# The city name is Sisimiut & the city id is 3419842
# The city name is Kattivakkam & the city id is 1267433
# CITY NOT VALID
# The city name is Kuito & the city id is 3348078
# The city name is Souris & the city id is 6151456
# The city name is Ubari & the city id is 2219235
# The city name is Port-Gentil & the city id is 2396518
# The city name is Kashgar & the city id is 1280849
# The city name is Bulawayo & the city id is 894701
# The city name is Suarez & the city id is 3667773
# The city name is Baie-Comeau & the city id is 5889745
# The city name is Yarim & the city id is 69559
# The city name is Zarate & the city id is 3427213
# The city name is Tiznit & the city id is 2527087
# The city name is Dergachi & the city id is 566456
# The city name is Punta Cardon & the city id is 3629614
# The city name is Moose Factory & the city id is 6078372
# The city name is Marquette & the city id is 5000950
# The city name is Bondo & the city id is 218253
# The city name is Muisne & the city id is 3653967
# The city name is Holland & the city id is 4996248
# The city name is Vawkavysk & the city id is 620391
# The city name is Ambikapur & the city id is 1278827
# The city name is Bathsheba & the city id is 3374083
# The city name is Ilhabela & the city id is 3461425
# The city name is Pforzheim & the city id is 2853969
# The city name is Garoowe & the city id is 58933
# The city name is Abay & the city id is 1526970
# The city name is Novo Aripuana & the city id is 3663142
# The city name is Kismayo & the city id is 55671
# The city name is Kalininskaya & the city id is 554173
# The city name is Sahbuz & the city id is 147278
# The city name is Kawambwa & the city id is 176555
# The city name is Shelburne & the city id is 6145890
# The city name is Faya & the city id is 110690
# The city name is Saint-Augustin & the city id is 6137462
# The city name is Laas & the city id is 3175096
# The city name is Wanlaweyn & the city id is 50672
# The city name is Caravelas & the city id is 3466980
# CITY NOT VALID
# The city name is Trelew & the city id is 3833883
# The city name is Mezen & the city id is 527321
# The city name is Beira & the city id is 1052373
# The city name is Cervo & the city id is 3125287
# CITY NOT VALID
# The city name is Bridgetown & the city id is 3374036
# The city name is Camana & the city id is 3945985
# The city name is Alekseyevskaya & the city id is 582816
# The city name is Calahorra & the city id is 3127065
# The city name is Camacha & the city id is 2270385
# The city name is Turbat & the city id is 1163054
# The city name is Krasnoznamensk & the city id is 6417459
# The city name is Mossamedes & the city id is 3347019
# The city name is Pokhara & the city id is 1282898
# The city name is Moyale & the city id is 186180
# The city name is Timmins & the city id is 6166739
# The city name is Kelamangalam & the city id is 1267331
# The city name is Natal & the city id is 3394023
# The city name is Manaus & the city id is 3663517
# The city name is Turhal & the city id is 738618
# The city name is Rocha & the city id is 3440777
# The city name is Farafenni & the city id is 2413515
# The city name is Birmitrapur & the city id is 1275506
# The city name is Ust-Tsilma & the city id is 477940
# The city name is Plettenberg Bay & the city id is 964712
# The city name is Semnan & the city id is 116402
# The city name is Grand Gaube & the city id is 934479
# The city name is Mitu & the city id is 3674676
# The city name is Cabanas & the city id is 3566573
# The city name is Vysha & the city id is 470304
# The city name is Casa Nova & the city id is 3402621
# The city name is Agirish & the city id is 1512101
# The city name is Ziarat & the city id is 1162094
# The city name is Kedrovyy & the city id is 1538641
# The city name is Marzuq & the city id is 72181
# The city name is Saint-Francois & the city id is 2980080
# The city name is Conceicao do Araguaia & the city id is 3401845
# The city name is Rawah & the city id is 92004
# CITY NOT VALID
# The city name is Nicoya & the city id is 3622716
# The city name is Joshimath & the city id is 1268814
# The city name is Cahul & the city id is 618456
# The city name is Harar & the city id is 335035
# The city name is Bonavista & the city id is 5905393
# The city name is Santa Rosa & the city id is 1687894
# The city name is Kiryat Gat & the city id is 293842
# The city name is Trairi & the city id is 3386177
# The city name is Harper & the city id is 2276492
# The city name is Locri & the city id is 2524371
# The city name is Viedma & the city id is 3832899
# The city name is Salinopolis & the city id is 3389822
# The city name is Biltine & the city id is 244878
# CITY NOT VALID
# The city name is Luanda & the city id is 2240449
# The city name is Mercedes & the city id is 3430708
# The city name is Kotelnikowo & the city id is 543728
# The city name is Santiago del Estero & the city id is 3835869
# The city name is Kirando & the city id is 157107
# The city name is Pudozh & the city id is 504269
# The city name is Hoeganaes & the city id is 2706003
# The city name is Tera & the city id is 2438855
# The city name is Honningsvag & the city id is 779554
# The city name is Laguna & the city id is 5364271
# The city name is Peniche & the city id is 2264923
# The city name is Urengoy & the city id is 1488414
# The city name is Avanuorri & the city id is 779622
# The city name is Kargasok & the city id is 1504382
# The city name is Beloha & the city id is 1067565
# The city name is Grindu & the city id is 676720
# The city name is Quatre Cocos & the city id is 1106643
# The city name is Araripe & the city id is 3407248
# The city name is Saint-Louis & the city id is 2246451
# The city name is Santa Vitoria do Palmar & the city id is 3449747
# The city name is San Jose & the city id is 5392171
# The city name is Cockburn Town & the city id is 3576994
# The city name is Pyaozerskiy & the city id is 503581
# The city name is Gobabis & the city id is 3357247
# The city name is Cavadinesti & the city id is 682511
# The city name is Silva Jardim & the city id is 3447591
# The city name is Sonqor & the city id is 114049
# The city name is Presidente Olegario & the city id is 3452327
# The city name is Nantucket & the city id is 4944903
# The city name is Saint-Pierre & the city id is 935214
# CITY NOT VALID
# CITY NOT VALID
# The city name is Neuquen & the city id is 3843123
# The city name is Neyveli & the city id is 1253080
# The city name is Akdepe & the city id is 601551
# The city name is Major Isidoro & the city id is 3395880
# The city name is Saurimo & the city id is 145531
# The city name is Miraflores & the city id is 3761194
# The city name is Kabinda & the city id is 215527
# The city name is Tabalosos & the city id is 3691638
# The city name is Coyhaique & the city id is 3894426
# The city name is Menzel Kamel & the city id is 2469255
# The city name is Correntina & the city id is 3465373
# The city name is Rafai & the city id is 236524
# The city name is Lethem & the city id is 3379316
# The city name is Isil'kul' & the city id is 1505438
# The city name is Isiro & the city id is 215771
# CITY NOT VALID
# The city name is Bariadi & the city id is 161218
# The city name is Jalu & the city id is 86049
# The city name is Abha & the city id is 110690
# The city name is Borovoy & the city id is 1508894
# The city name is Mecca & the city id is 104515
# The city name is Puerto Escondido & the city id is 3520994
# The city name is Maceio & the city id is 3395981
# The city name is Arica & the city id is 3899361
# The city name is Ndjole & the city id is 2397674
# The city name is Tambura & the city id is 366444
# The city name is Kortkeros & the city id is 544397
# The city name is Yvetot & the city id is 2967189
# The city name is Mutoko & the city id is 884927
# The city name is Yeovil & the city id is 2633373
# The city name is Ligatne & the city id is 457912
# The city name is Aksarka & the city id is 1512019
# The city name is Clyde River & the city id is 5924351
# The city name is Paro & the city id is 1252490
# The city name is Puerto Baquerizo Moreno & the city id is 3652758
# The city name is Aksu & the city id is 1529660
# The city name is Paita & the city id is 3694112
# The city name is Mbandaka & the city id is 2312895
# CITY NOT VALID
# The city name is Klaksvik & the city id is 2618795
# The city name is Tevriz & the city id is 1489661
# CITY NOT VALID
# The city name is Carutapera & the city id is 3402648
# The city name is Tsiroanomandidy & the city id is 1054463
# CITY NOT VALID
# The city name is Eten & the city id is 3697083
# The city name is Mogapi & the city id is 933333
# The city name is Hofn & the city id is 2630299
# The city name is Lisakovsk & the city id is 1521315
# The city name is Ambilobe & the city id is 1082243
# The city name is Qaqortoq & the city id is 3420846
# The city name is Manaure & the city id is 3675504
# CITY NOT VALID
# The city name is Sinnamary & the city id is 3380290
# The city name is Gigant & the city id is 561501
# The city name is Kovdor & the city id is 543508
# The city name is Trinidad & the city id is 3902377
# The city name is Meschede & the city id is 2871668
# The city name is Gloversville & the city id is 5118743
# CITY NOT VALID
# The city name is Buenos Aires & the city id is 3435910
# The city name is Port Saint Lucie & the city id is 4169171
# The city name is Deer Lake & the city id is 5937252
# The city name is Marrakesh & the city id is 2542997
# The city name is Gostinu & the city id is 676858
# The city name is Kavaratti & the city id is 1267390
# The city name is Taoudenni & the city id is 2450173
# The city name is Tapes & the city id is 3446880
# The city name is Tambopata & the city id is 3927942
# The city name is Atasu & the city id is 1526041
# The city name is La Palma & the city id is 5364022
# CITY NOT VALID
# The city name is Iquitos & the city id is 3696183
# The city name is Nibbar & the city id is 2468459
# The city name is Ruwi & the city id is 287286
# The city name is Aden & the city id is 415189
# The city name is Amiens & the city id is 3037854
# The city name is Luderitz & the city id is 3355672
# The city name is Bahia Blanca & the city id is 3865086
# The city name is Cheremnoye & the city id is 1508230
# The city name is Kudahuvadhoo & the city id is 1337607
# The city name is Sambava & the city id is 1056899
# The city name is Carnarvon & the city id is 2074865
# The city name is Santona & the city id is 3109527
# The city name is Rondonopolis & the city id is 3450909
# The city name is Shar & the city id is 1519275
# CITY NOT VALID
# The city name is Chimbote & the city id is 3698304
# The city name is Santa Maria & the city id is 3450083
# The city name is Ambanja & the city id is 1083724
# The city name is Llallagua & the city id is 3911409
# The city name is Matara & the city id is 1235846
# The city name is Kalmunai & the city id is 1242110
# The city name is Rantoul & the city id is 4907131
# The city name is Millinocket & the city id is 4972220
# The city name is Gratia & the city id is 676783
# The city name is Sumy & the city id is 692194
# The city name is Muyezerskiy & the city id is 524100
# The city name is Sebinkarahisar & the city id is 739914
# The city name is Senanga & the city id is 898947
# The city name is Mansa & the city id is 1263622
# The city name is Manama & the city id is 290340
# The city name is Mapiripan & the city id is 3792394
# The city name is Gelemso & the city id is 337010
# The city name is Abu Dhabi & the city id is 292968
# The city name is Kama & the city id is 553878
# The city name is Reconquista & the city id is 3429594
# The city name is Potosi & the city id is 3907584
# The city name is Rio Grande & the city id is 3451138
# The city name is Havelock & the city id is 4470244
# The city name is Jaipur & the city id is 1269515
# The city name is Ancud & the city id is 3899695
# The city name is Santa Cruz de la Sierra & the city id is 3904906
# The city name is Porto Nacional & the city id is 3452711
# The city name is Veraval & the city id is 1253237
# The city name is Sandwick & the city id is 2638534
# The city name is Sirte & the city id is 2210554
# The city name is Kafanchan & the city id is 2335713
# The city name is Zapolyarnyy & the city id is 464790
# The city name is Iskateley & the city id is 866062
# CITY NOT VALID
# CITY NOT VALID
# The city name is Dingle & the city id is 1714733
# CITY NOT VALID
# The city name is Hambantota & the city id is 1244926
# The city name is Ramshir & the city id is 118805
# The city name is Oranjestad & the city id is 3577154
# The city name is Arrondissement de Saint-Denis & the city id is 2980915
# The city name is Minna & the city id is 2330100
# The city name is Cape Canaveral & the city id is 4149959
# The city name is Kibre Mengist & the city id is 333103
# The city name is Sohbatpur & the city id is 1164660
# The city name is Karakol & the city id is 1528121
# The city name is San Andres & the city id is 3670218
# The city name is Nobres & the city id is 3456277
# The city name is Urgut & the city id is 1215839
# The city name is Sawakin & the city id is 367544
# The city name is Yahotyn & the city id is 688587
# The city name is Kathmandu & the city id is 1283240
# The city name is Koundara & the city id is 2418596
# The city name is Maua & the city id is 3457381
# The city name is Hukuntsi & the city id is 933726
# The city name is Luba & the city id is 2309528
# The city name is Wadsworth & the city id is 5175496
# The city name is Damavand & the city id is 138042
# The city name is Mutare & the city id is 884979
# The city name is Tazovsky & the city id is 1489853
# The city name is Itapirapua & the city id is 3460697
# The city name is Rovnoye & the city id is 501091
# CITY NOT VALID
# The city name is Sao Felix do Xingu & the city id is 3388847
# The city name is Tallahassee & the city id is 4174715
# The city name is Alta & the city id is 847633
# The city name is Zhuravka & the city id is 687009
# The city name is Fuerte Olimpo & the city id is 3438102
# The city name is Tupelo & the city id is 4448903
# The city name is Amapa & the city id is 3407762
# The city name is Khorixas & the city id is 3356213
# The city name is Bengkulu & the city id is 1649150
# The city name is Saint-Joseph & the city id is 6690296
# The city name is Kambove & the city id is 923058
# The city name is Jaisalmer & the city id is 1269507
# CITY NOT VALID
# CITY NOT VALID
# The city name is Portree & the city id is 2640006
# The city name is Bumba & the city id is 217745
# The city name is Caala & the city id is 3351500
# The city name is Muli & the city id is 1337617
# The city name is Manta & the city id is 3654410
# The city name is Geraldton & the city id is 2070998
# The city name is Obo & the city id is 236950
# The city name is North Myrtle Beach & the city id is 4589446
# The city name is Moroni & the city id is 921772
# The city name is Sabratah & the city id is 2212771
# The city name is Havre-Saint-Pierre & the city id is 5972291
# CITY NOT VALID
# The city name is Buraidah & the city id is 107304
# CITY NOT VALID
# The city name is Gamboula & the city id is 2386756
# The city name is Adrar & the city id is 2381972
# The city name is Boddam & the city id is 2655288
# The city name is Urdoma & the city id is 478769
# The city name is Puerto Leguizamo & the city id is 3671437
# The city name is Cayenne & the city id is 3382160
# The city name is Inhambane & the city id is 1045114
# The city name is Bajil & the city id is 77408
# The city name is Kontagora & the city id is 2334008
# CITY NOT VALID
# The city name is Black River & the city id is 3491355
# The city name is Sotnikovskoye & the city id is 490108
# The city name is Varhaug & the city id is 3132644
# The city name is Verin & the city id is 3106086
# The city name is Misratah & the city id is 2214846
# The city name is Ipixuna & the city id is 3408424
# The city name is Kamenka & the city id is 553766
# The city name is Khunti & the city id is 1266622
# The city name is Zabid & the city id is 69500
# The city name is Bad Sachsa & the city id is 2953364
# The city name is Carballo & the city id is 3126369
# CITY NOT VALID
# The city name is Petra & the city id is 246008
# The city name is Port Blair & the city id is 1259385
# The city name is Goundi & the city id is 2431736
# The city name is Goma & the city id is 216281
# The city name is Noyabrsk & the city id is 1496503
# The city name is Orange Walk District & the city id is 3581511
# The city name is Pauini & the city id is 3662927
# The city name is Cullinan & the city id is 1012413
# The city name is Kutum & the city id is 371745
# The city name is Atar & the city id is 2381334
# The city name is Filingue & the city id is 2444995
# The city name is Meiganga & the city id is 2227402
# The city name is Bichena & the city id is 342190
# The city name is Malanje & the city id is 2239862
# CITY NOT VALID
# The city name is Platanos & the city id is 255030
# The city name is Inverness & the city id is 2646088
# The city name is Paragominas & the city id is 3393106
# The city name is Wajir & the city id is 178443
# The city name is Nabadwip & the city id is 1261669
# The city name is Slidell & the city id is 4341727
# The city name is Jose Bonifacio & the city id is 3459667
# The city name is Rio Gallegos & the city id is 3838859
# The city name is Pasni & the city id is 1168312
# The city name is Dakar & the city id is 2253354
# CITY NOT VALID
# CITY NOT VALID
# The city name is Esim & the city id is 2303611

# %%
new_dic = ({"City Name": new_name, "Tempurature": temp, "Latitude": lat, "Longitude": lon, "Wind Spd": windspd, "Humidity %": humidity, "Cloud %": cloudiness})
new_df = pd.DataFrame(new_dic)
new_df.head()
# Out:
#       City Name  Tempurature  Latitude  Longitude  Wind Spd  Humidity %  \
# 0       Ushuaia        43.57    -54.80     -68.30     41.38          93
# 1        Narsaq        10.40     60.92     -46.05      9.55          51
# 2        Dikson        -8.95     73.51      80.55     12.17         100
# 3  Longyearbyen        -7.60     78.22      15.64      2.24          83
# 4       Qaanaaq       -13.72     77.48     -69.36      4.76          46
#
#    Cloud %
# 0       90
# 1       62
# 2      100
# 3       20
# 4        0

# %%
plt.scatter(new_df["Latitude"], new_df["Tempurature"], alpha=.7)
plt.xlabel("Cities Latitude")
plt.ylabel("Cities Temp (F)")
plt.title("Tempurature (F) vs. Latitude")
# Out:
# Text(0.5, 1.0, 'Tempurature (F) vs. Latitude')

# %%
plt.scatter(new_df["Latitude"], new_df["Humidity %"], alpha=.7)
plt.xlabel("Cities Latitude")
plt.ylabel("Cities Humidity (%)")
plt.title("Humidity (%) vs. Latitude")
# Out:
# Text(0.5, 1.0, 'Humidity (%) vs. Latitude')

# %%
plt.scatter(new_df["Latitude"], new_df["Cloud %"], alpha=.7)
plt.xlabel("Cities Latitude")
plt.ylabel("Cities Cloudiness (%)")
plt.title("Couldiness (%) vs. Latitude")
# Out:
# Text(0.5, 1.0, 'Couldiness (%) vs. Latitude')

# %%
plt.scatter(new_df["Latitude"], new_df["Wind Spd"], alpha=.7)
plt.xlabel("Cities Latitude")
plt.ylabel("Cities Wind Spd (mph)")
plt.title("Wind Spd (mph) vs. Latitude")
# Out:
# Text(0.5, 1.0, 'Wind Spd (mph) vs. Latitude')

# %%
#new_df.loc[]
north_hem = new_df.loc[new_df["Latitude"] >= 0, :]
#north_hem
south_hem = new_df.loc[new_df["Latitude"] < 0, :]
south_hem.head()
# Out:
#       City Name  Tempurature  Latitude  Longitude  Wind Spd  Humidity %  \
# 0       Ushuaia        43.57    -54.80     -68.30     41.38          93
# 6   Port Alfred        72.00    -33.59      26.89      1.99          95
# 7     Busselton        61.56    -33.65     115.33     13.98          45
# 9      Hermanus        73.99    -34.42      19.23      4.00          84
# 10     Altamira        87.80     -3.20     -52.21      2.24          74
#
#     Cloud %
# 0        90
# 6        99
# 7         0
# 9        33
# 10       40

# %%
x_values = north_hem['Latitude'].astype('float')
y_values = north_hem['Tempurature'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Northern Hem - Latitude")
plt.ylabel("Norther Hem - Tempurature")
plt.title("Northern Hem - Lat vs. Temp")
print(f"{rvalue}")
# Out:
# -0.8423094563056379

# %%
x_values = south_hem['Latitude'].astype('float')
y_values = south_hem['Tempurature'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Tempurature")
plt.title("Southern Hem - Lat vs. Temp")
print(f"{rvalue}")
# Out:
# 0.3503654129356217

# %%
x_values = north_hem['Latitude'].astype('float')
y_values = north_hem['Humidity %'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Northern Hem - Lat vs. Humidity %")
print(f"{rvalue}")
# Out:
# 0.5009849775541773

# %%
x_values = south_hem['Latitude'].astype('float')
y_values = south_hem['Humidity %'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Southern Hem - Lat vs. Humidity %")
print(f"{rvalue}")
# Out:
# 0.2948814374522166

# %%
x_values = north_hem['Latitude'].astype('float')
y_values = north_hem['Cloud %'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Could %")
plt.title("Northern Hem - Lat vs. Cloud %")
print(f"{rvalue}")
# Out:
# 0.3629793413318673

# %%
x_values = south_hem['Latitude'].astype('float')
y_values = south_hem['Cloud %'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloud %")
plt.title("Southern Hem - Lat vs. Cloud %")
print(f"{rvalue}")
# Out:
# 0.029328728274311336

# %%
x_values = north_hem['Latitude'].astype('float')
y_values = north_hem['Wind Spd'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Spd")
plt.title("Northern Hem - Lat vs. Wind Spd")
print(f"{rvalue}")
# Out:
# 0.15914780258281758

# %%
x_values = south_hem['Latitude'].astype('float')
y_values = south_hem['Wind Spd'].astype('float')

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)

plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Spd")
plt.title("Southern Hem - Lat vs. Wind Spd")
print(f"{rvalue}")
# Out:
# -0.4254489573260296

# %%
new_df.to_csv('MapData.csv')
